# %% [markdown]
# <a href="https://colab.research.google.com/github/jrakhshanda/Bayesian-Methods/blob/master/Association_rule_mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Association Rule Mining

# %%
# !pip install apyori

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from apyori import apriori
import re

import pickle
import os
from os.path import isfile, join
import string
from ast import literal_eval
from google.colab import files

# %%
def save_object(path, filename, obj):
    print('Saving Object')
    path_file = join(path, filename)    
    pickle.dump(obj, open(path_file, 'wb'))
    print('Save complete')

def load_object(path, filename):
    print('Attempting to Load Object')
    path_file = join(path, filename)    
    obj = pickle.load(open(path_file, "rb" ))
    print('Load complete')
    return obj

def save_csv(path, filename, dataframe):
    print('Saving Dataframe to CSV')
    path_file = join(path, filename)    
    dataframe.to_csv(path_file, index=False)

def load_csv(path, filename):
    print('Loading Dataframe From CSV')
    path_file = join(path, filename)
    dataframe = pd.read_csv(path_file)
    return dataframe

# %%
def flatten(input_list):
    '''
    A function to flatten complex list.
    :param input_list: The list to be flatten
    :return: the flattened list.
    '''
    flat_list = []
    for i in input_list:
        if type(i) == list:
            flat_list += flatten(i)
        else:
            flat_list += [i]

    return flat_list

# %% [markdown]
# # Data and Pre processing

# %%
df = pd.read_csv('/content/drive/MyDrive/cancer_data/gene_cancer.csv')
df.head()
# Out:
#        PMID  ...                                   gene_association
# 0  33609553  ...          ['hMC5R', 'MSH', 'melanocortin', 'hMC4R']
# 1  33609447  ...                                  ['BRCA2', 'VUSs']
# 2  33608585  ...                                            ['UPR']
# 3  33607478  ...                 ['synaptophysin', 'Synaptophysin']
# 4  33606355  ...  ['Aurora', 'BRCA1', 'containing', 'RACK1', 'BA...
#
# [5 rows x 5 columns]

# %%
syno = pd.read_csv('/content/synonom_genes.txt',delimiter='\t')
syno.columns = ['synonm','gene']
syno['gene'] = syno['gene'].apply(lambda x: re.sub('[^A-Za-z0-9]+', ' ', x))
syno['gene'] = syno['gene'].astype('string')
syno['synonm'] = syno['synonm'].astype('string')

# %%
#save_object('/content/drive/MyDrive/cancer_data','gene_dictionary',dictionary)
dictionary = load_object('/content/drive/MyDrive/cancer_data','gene_dictionary')

# %%
gene = [literal_eval(x) for x in df['Gene']]
gene = [[x for x in sublist if (x in dictionary)] for sublist in gene]

# %%
abr = pd.read_csv('/content/drive/MyDrive/cancer_data/cancer_abreviations')
abr.head()
# Out:
#   Abbreviation                          Long_Form
# 0        NAD(+  Nicotinamide adenine dinucleotide
# 1        hMC1R      human melanocortin 1 receptor
# 2           UV              ultraviolet radiation
# 3          HDR       homology-directed DNA repair
# 4          PCa                    Prostate cancer

# %%
def Filter(list1, list2): 
    return [x for x in list1 if all(y not in x for y in list2)]
stops = ['tumor','tumours','tumour','tumors','anti','cell','tissue','line','vus','biopsy','therapy','rt sns','specimen','deficient','raid','mutate','iii','ii','stage','poly',
         'related','brca','proficient','high','grade','xenografts','resistant']
stop_words = ['cancer','breast','ovarian','left kidney','ovarian']

# %%
cancer = [literal_eval(x) for x in df['cancer_association']]
cancer = [list(set(sublist)) for sublist in cancer]
cancer = [[x.replace('-', ' ') for x in sublist] for sublist in cancer]
cancer = [[x.replace('cancers', 'cancer') for x in sublist] for sublist in cancer]
cancer = [[re.sub("\S*\d\S*", "", x).strip() for x in sublist] for sublist in cancer] # removing words which contains difits
cancer = [[x for x in sublist if x] for sublist in cancer]
cancer = [Filter(x,stops) for x in cancer]

# %%
cancer
# Out:
# [['melanoma', 'skin cancer'],
#  [],
#  ['prostate cancer'],
#  ['epithelial cancer', 'colorectal cancer', 'mucinous adenocarcinoma'],
#  ['breast cancer', 'ovarian cancer'],
#  ['escc biopsies', 'escc', 'esophageal carcinoma'],
#  ['mucinous', 'colorectal cancer'],
#  ['bladder cancer'],
#  ['nasopharyngeal carcinoma', 'npc'],
#  ['gastric cancer'],
#  ['gastric carcinoma'],
#  ['ovarian cancer', 'breast cancer', 'prostate cancer', 'breast ovary cancer'],
#  [],
#  [],
#  ['pdac', 'pancreatic ductal adenocarcinoma'],
#  [],
#  ['rcc', 'kidney cancer', 'renal cancer'],
#  ['colorectal cancer', 'metastatic colorectal cancer'],
#  ['mcrpc', 'prostate cancer'],
#  ['colorectal cancer'],
#  ['histotypes', 'endometrial cancer', 'endometrial cancer'],
#  ['urothelial carcinoma',
#   'utuc',
#   'genitourinary malignancy',
#   'upper tract uc'],
#  ['lung cancer', 'lung adenocarcinoma'],
#  ['cervical cancer', 'breast cancer'],
#  ['ovarian'],
#  ['triple negative breast cancer',
#   'breast cancer',
#   'benign breast disease',
#   'triple negative breast cancer',
#   'bbb cancer'],
#  ['breast cancer'],
#  ['pancreatic cancer'],
#  ['sclc'],
#  [],
#  ['gastrointestinal cancer', 'pancreatic'],
#  ['neuroblastoma'],
#  [],
#  ['ovarian cancer'],
#  [],
#  ['prostate cancer',
#   'prostate cancer biopsies',
#   'lung cancer liquid',
#   'prostatic cancer'],
#  ['thyroid cancer'],
#  ['glioblastoma'],
#  ['pancreatic cancer'],
#  ['gastric cancer', 'colorectal cancer'],
#  ['head neck region',
#   'lymph node negative cutaneous melanoma',
#   'cutaneous melanoma',
#   'melanoma'],
#  ['head neck cancer'],
#  ['dependent', 'osteosarcoma', 'colon adenocarcinoma', 'melanoma'],
#  ['msi', 'pole  mutant cancer'],
#  [],
#  [],
#  ['pan cancer', 'solid neoplasms', 'glioblastoma', 'ovarian cancer'],
#  ['breast cancer', 'triple negative breast cancer'],
#  ['breast cancer'],
#  ['head neck cancer'],
#  ['ctc driven', 'ctcs', 'ctc'],
#  ['gbm', 'breast cancer', 'glioblastoma', 'astrocytoma'],
#  ['skin cancer'],
#  ['gastrointestinal cancer', 'non colorectal digestive cancer', 'msi'],
#  ['hcc'],
#  ['breast cancer', 'estrogen dependent'],
#  ['bladder cancer'],
#  ['breast cancer'],
#  ['gastric cancer'],
#  ['breast cancer', 'triple negative breast cancer'],
#  [],
#  [],
#  ['breast cancer'],
#  [],
#  ['ovarian cancer', 'hgsoc'],
#  ['endometrial cancer'],
#  [],
#  ['bcc'],
#  ['thyroid cancer', 'benign thyroid nodules'],
#  ['glioblastoma'],
#  [],
#  ['aitl', 'ptcl', 'ptcls'],
#  [],
#  ['head neck cancer',
#   'head neck carcinoma',
#   'm arrest',
#   'hpv positive xenograft',
#   'hpv positive hnscc',
#   'hnscc'],
#  ['dmmr cancer'],
#  ['gastric cancer', 'thyroid cancer'],
#  ['mammary ductal carcinoma', 'invasive ductal mammary carcinoma'],
#  ['anaplastic thyroid cancer', 'anaplastic thyroid carcinoma'],
#  ['aml', 'acute myeloid leukemia'],
#  ['advanced cancer', 'breast cancer', 'triple negative breast cancer'],
#  [],
#  ['adenocarcinoma', 'brain cancer', 'anaplastic astrocytoma'],
#  ['mesothelioma'],
#  ['nasopharyngeal carcinoma'],
#  ['rectal cancer'],
#  ['glioma', 'gliomas'],
#  ['pdac', 'pancreatic ductal adenocarcinoma', 'pancreatic cancer'],
#  ['epithelial ovarian cancer', 'eoc', 'hgsoc', 'ovarian carcinoma'],
#  ['papillary thyroid carcinoma', 'ptc'],
#  ['gynecological ls surveillance',
#   'ovarian cancer',
#   'endometrial cancer',
#   'gynecological malignancy'],
#  ['urothelial cancer',
#   'ovarian cancer',
#   'pancreatic cancer',
#   'gastric cancer',
#   'colon cancer',
#   'capsule endoscopy',
#   'adrenocortical carcinoma',
#   'rectal adenocarcinoma',
#   'sebaceous carcinoma',
#   'adenomas',
#   'keratoacanthomas',
#   'breast',
#   'sebaceous adenomas',
#   'colorectal cancer',
#   'glioblastoma',
#   'sarcomas'],
#  ['bladder cancer'],
#  ['escc',
#   'esophageal carcinoma',
#   'esophageal cancer',
#   'upper gastrointestinal cancer'],
#  ['bowel adenocarcinoma', 'msi'],
#  ['skin cutaneous melanoma'],
#  ['colorectal cancer', 'colorectal cancer'],
#  ['pdac', 'pancreatic cancer', 'pancreatic ductal adenocarcinoma'],
#  ['ovarian cancer'],
#  ['leukemia'],
#  ['colorectal cancer',
#   'keratoacanthomas',
#   'keratoacanthoma',
#   'sebaceous adenomas',
#   'sebaceous neoplasms'],
#  ['triple negative breast cancer',
#   'unresectable',
#   'breast cancer',
#   'mtriple negative breast cancer'],
#  ['glioma'],
#  ['pan cancer',
#   'colitis associated colorectal carcinoma',
#   'ulcerative colitis associated colorectal cancer'],
#  ['colorectal cancer'],
#  ['pan cancer', 'msi', 'kidney renal', 'kirc', 'ccle'],
#  ['pdac',
#   'pancreatic cancer',
#   'pancreatic',
#   'breast cancer',
#   'pdacs',
#   'pancreatic ductal adenocarcinoma'],
#  [],
#  ['osteosarcoma', 'osteosarcomas'],
#  ['colorectal cancer'],
#  ['gastric cancer', 'hcc'],
#  ['aml'],
#  [],
#  [],
#  ['liver cancer'],
#  [],
#  ['endocrine mucin producing sweat gl carcinoma',
#   'neuroendocrine pathology',
#   'sweat gl carcinoma'],
#  ['upper respiratory tract', 'malignant mesothelioma'],
#  ['larval'],
#  ['gastric cancer'],
#  ['solid cancer'],
#  ['ovarian cancer', 'epithelial ovarian cancer'],
#  ['non seminomas', 'tgastric cancerts', 'tgastric cancert', 'seminomas'],
#  [],
#  [],
#  ['myeloma', 'blood cancer', 'solid organ cancer'],
#  ['crt', 'rectal cancer'],
#  ['relapsed sclc', 'lung cancer', 'sclc'],
#  ['lung cancer'],
#  ['oropharyngeal carcinoma', 'lnm', 'opscc'],
#  ['gastric cancer'],
#  ['bccs', 'bcc', 'breast cancer'],
#  [],
#  ['bladder cancer'],
#  [],
#  ['barrett s like metaplasia',
#   'squamous organoids',
#   'esophageal s',
#   'squamous cytokeratins',
#   'barrett s metaplasia',
#   'gerd',
#   'barrett s esophagus',
#   'squamous esophageal epithelium'],
#  ['cachexia', 'colon cancer'],
#  ['mcrpc', 'prostate cancer'],
#  ['breast cancer'],
#  ['colorectal cancer'],
#  ['breast cancer'],
#  ['esophageal carcinoma', 'escc'],
#  ['cervical cancer'],
#  [],
#  ['ovarian cancer',
#   'epithelial ovarian cancer',
#   'breast cancer',
#   'eoc',
#   'metastatic breast cancer'],
#  ['epithelial ovarian cancer', 'ovarian cancer', 'eoc', 'epithelial eoc'],
#  ['breast cancer'],
#  ['lung adenocarcinoma'],
#  ['colonic cancer',
#   'nhl',
#   'non hodgkin s lymphoma',
#   'colonic neoplasm',
#   'adenocarcinoma colon',
#   'colorectal carcinoma',
#   'glioblastoma'],
#  ['nhl',
#   'non hodgkin lymphoma',
#   'nbs',
#   'malignancy',
#   'lymphoid malignancies',
#   'hsct'],
#  ['breast cancer', 'ovarian'],
#  [],
#  ['colorectal cancer', 'colorectal cancer a'],
#  ['oesophageal carcinoma', 'oscc'],
#  ['hcc sorafenib', 'xenograft mouse', 'hcc'],
#  ['ovarian cancer', 'hboc', 'breast', 'endometrial cancer'],
#  ['bph', 'benign prostatic hyperplasia', 'prostate cancer', 'prostate cancer'],
#  ['epithelial ovarian cancer', 'eoc', 'ovarian cancer'],
#  ['cervical cancer', 'cervical carcinoma'],
#  ['glioma'],
#  ['breast cancer', 'triple negative breast cancer'],
#  ['amplified breast cancer', 'positive breast cancer'],
#  [],
#  ['rectal adenoma',
#   'colon carcinoma',
#   'cecum colon cancer',
#   'gynecological cancer',
#   'rectal cancer',
#   'colorectal cancer'],
#  ['colorectal cancer', 'wes wgs'],
#  ['endometrial cancer'],
#  ['n methyl n nitrosourea nmu induced colorectal cancer',
#   'mucinous colorectal cancer',
#   'colorectal cancer',
#   'nmu induced colorectal cancer'],
#  ['anaplastic thyroid cancer',
#   'triple negative breast cancer',
#   'invasive ductal carcinoma',
#   'pancreatic ductal adenocarcinoma',
#   'glioblastoma'],
#  ['malignant pleural mesothelioma',
#   'uveal melanoma',
#   'breast',
#   'bladder cancer',
#   'intrahepatic cholangiocarcinoma',
#   'pancreatic'],
#  ['breast cancer'],
#  ['aml'],
#  ['gastric cancer'],
#  ['colorectal carcinoma', 'colorectal cancer'],
#  ['pancreatic cancer'],
#  [],
#  ['metastatic prostate cancer', 'prostate cancer'],
#  ['rogen responsive', 'prostate cancer'],
#  ['prostate cancer'],
#  [],
#  ['endometrial carcinoma', 'endometrial cancer'],
#  [],
#  [],
#  ['hgsoc', 'non', 'endometrial cancer'],
#  ['tme based', 'small intestinal adenocarcinoma'],
#  ['lung cancer', 'lung adenocarcinoma', 'luad', 'copd'],
#  ['pscc', 'hnsc', 'head neck carcinoma', 'penile carcinoma', 'sccs'],
#  ['ve breast cancer', 'breast cancer'],
#  ['gepia', 'pancreatic adenocarcinoma', 'paad'],
#  ['ovarian cancer'],
#  ['malignant neoplasms', 'left limb'],
#  ['gbm', 'glioblastoma'],
#  ['brain cancer', 'glioblastoma'],
#  ['nasopharyngeal carcinoma', 'npc'],
#  ['cutaneous melanoma', 'mucosal melanomas', 'cutaneous melanomas'],
#  ['melanoma xenograft', 'melanoma'],
#  [],
#  ['urothelial cancer',
#   'upper urinary tract',
#   'urothelial carcinoma',
#   'hnpcc',
#   'colorectal cancer'],
#  ['colorectal cancer', 'mcolorectal cancer'],
#  ['colorectal cancer', 'breast cancer'],
#  ['leukemia'],
#  ['colorectal cancer'],
#  ['triple negative breast cancer'],
#  ['prostatic adenocarcinoma', 'rogen independent', 'prostate cancer'],
#  ['luad', 'lung adenocarcinoma'],
#  ['breast cancer', 'triple negative breast cancer'],
#  ['claudin low', 'urothelial carcinoma'],
#  ['breast cancer', 'triple negative breast cancer'],
#  ['triple negative breast cancer',
#   'breast cancer',
#   'triple negative metastatic breast cancer',
#   'metastatic triple negative breast cancer'],
#  ['colorectal cancer'],
#  ['metaplastic histology', 'triple negative breast cancer', 'breast cancer'],
#  ['oligometastatic prostate cancer',
#   'oligometastatic cspc',
#   'crpc',
#   'prostate cancer',
#   'metastatic lesions',
#   'metachronous oligometastatic'],
#  ['breast cancer', 'breast carcinoma'],
#  ['lung cancer'],
#  [],
#  ['colorectal cancer', 'colon cancer'],
#  ['cibersort', 'ovarian ccc', 'hgsoc'],
#  ['gastric cancer'],
#  [],
#  [],
#  ['aml', 'acute myeloid leukemia'],
#  ['prostate cancer'],
#  ['renal carcinoma', 'kidney cancer', 'renal cancer'],
#  ['colorectal cancer', 'colorectal cancer'],
#  ['metastatic prostate cancer', 'prostate cancer'],
#  ['colorectal cancer'],
#  [],
#  ['ovarian cancer', 'breast cancer', 'triple negative breast cancer'],
#  ['breast cancer'],
#  ['gastric cancer', 'msi', 'gastric carcinoma'],
#  ['gi cancer', 'melanoma', 'colon cancer'],
#  ['ovarian cancer'],
#  ['osteosarcomas', 'rts', 'skin cancer'],
#  ['head neck cancer',
#   'xenograft mouse',
#   'ovarian cancer',
#   'lung cancer',
#   'esophageal cancer',
#   'lung carcinoma'],
#  ['colorectal cancer', 'colorectal cancer', 'parpi niraparib'],
#  ['colorectal cancer', 'non cancer'],
#  ['bladder cancer'],
#  ['endometrial carcinoma', 'gynecological malignancies', 'endometrial cancer'],
#  ['prostate cancer'],
#  ['intestinal cancer'],
#  ['myc driven'],
#  [],
#  ['papillary thyroid carcinoma', 'ptc'],
#  ['head neck carcinoma', 'hnscc', 'bladder cancer'],
#  [],
#  ['breast cancer'],
#  ['gbm', 'glioblastomas', 'gbms', 'glioblastoma'],
#  [],
#  ['chronic myelogenous leukemia', 'cml'],
#  ['colorectal adenocarcinoma'],
#  [],
#  ['acute promyelocytic leukemia'],
#  ['osteosarcoma', 'bone cancer'],
#  ['gastric cancer'],
#  ['ovarian cancer'],
#  ['luad', 'lung adenocarcinoma'],
#  ['prostate cancer'],
#  [],
#  ['colon cancer'],
#  ['primary breast cancer', 'breast cancer brain'],
#  [],
#  [],
#  ['colorectal cancer', 'renal cancer', 'endometrial cancer'],
#  ['relapsed lesions', 'relapsed', 'neuroblastoma'],
#  ['beta n glycosyl'],
#  [],
#  ['radiation induced byster effects'],
#  [],
#  ['leukemias', 'sarcoma'],
#  [],
#  ['pdac', 'pancreatic cancer', 'breast', 'pancreatic ductal adenocarcinoma'],
#  ['anln', 'pancreatic cancer'],
#  ['hcc'],
#  [],
#  ['gbm'],
#  ['akt mtor inhibitors', 'breast cancer'],
#  ['head neck carcinoma', 'hnsccs', 'hpv hnscc', 'hnscc'],
#  ['breast cancer', 'metastatic cancer'],
#  ['head neck cancer', 'oral cavity cancer', 'hnscc', 'head neck carcinoma'],
#  [],
#  ['pro cancer'],
#  ['oscc', 'oral carcinoma', 'lung adenocarcinoma', 'luad', 'hcc'],
#  [],
#  ['colorectal cancer', 'breast cancer'],
#  ['chronic myeloid leukemia', 'myeloid cancer', 'cp cml', 'cml'],
#  [],
#  [],
#  [],
#  ['ar positive prostate cancer', 'prostate cancer', 'synovial sarcoma'],
#  ['liver cancer'],
#  ['cervical carcinoma',
#   'cervical cancer',
#   'cervical adenocarcinoma',
#   'melanoma',
#   'non cancer'],
#  ['mcrpc'],
#  ['ovarian cancer', 'eoc', 'epithelial ovarian carcinoma'],
#  ['ovarian cancer'],
#  ['mds aml', 'secondary lesions', 'acute myeloid leukemia'],
#  ['head neck', 'pancreatic cancer', 'pancreas body'],
#  ['radiation induced'],
#  ['melanomas'],
#  [],
#  ['breast cancer', 'infiltrating ductal carcinoma'],
#  ['oral cancer', 'breast cancer', 'oral carcinoma'],
#  ['pancreatobiliary cancer', 'ampullary carcinoma', 'ampullary cancer'],
#  ['crpc', 'prostate cancer'],
#  ['ovarian', 'prostate cancer', 'pancreatic'],
#  [],
#  ['erg positive cancer', 'cancer', 'prostate cancer'],
#  [],
#  ['dmmr cancer'],
#  [],
#  ['ovarian'],
#  ['acute leukemia', 'aml', 'acute myeloid leukemia'],
#  ['mcrpc'],
#  ['luad', 'lung adenocarcinoma'],
#  ['osteosarcoma', 'medulloblastoma', 'adult cancer', 'neuroblastoma'],
#  ['uveal melanoma', 'metastasized um', 'um metastatic'],
#  ['hrd cancer'],
#  ['epithelial ovarian cancer'],
#  [],
#  ['colorectal cancer', 'mucinous adenocarcinoma'],
#  ['luad', 'lung adenocarcinoma'],
#  ['luad', 'luad subtypes', 'lung adenocarcinoma'],
#  ['metastatic intrahepatic cholangiocarcinoma',
#   'hepatobiliary cancer',
#   'intrahepatic cholangiocarcinoma'],
#  ['bulky lesions'],
#  ['cervical carcinoma', 'cervical cancer xenograft', 'cervical cancer'],
#  ['ovarian carcinoma', 'ovarian cancer'],
#  ['gallbladder cancer', 'gbc'],
#  ['myeloma'],
#  ['laser driven accelerators allow'],
#  ['cf ff group', 'cf ff individual', 'cf ff with'],
#  ['hboc', 'breast ovarian cancer'],
#  ['breast cancer', 'triple negative breast cancer'],
#  ['prostate cancer'],
#  ['neuroblastoma'],
#  [],
#  ['colon cancer', 'breast'],
#  [],
#  ['fibrosarcoma', 'chondrosarcoma', 'osteosarcoma'],
#  [],
#  ['colorectal cancer', 'gecco', 'colon cancer', 'rg'],
#  ['prostate cancer'],
#  ['bca', 'bladder cancer'],
#  ['immune recist', 'colorectal cancer', 'mcolorectal cancer'],
#  [],
#  [],
#  ['lung cancer', 'thymic hyperplasia'],
#  ['breast cancer'],
#  ['bladder urothelial carcinoma', 'prostate adenocarcinoma'],
#  ['triple negative breast cancer'],
#  ['oscc', 'oral cancer', 'oral carcinoma', 'precancer', 'opmds'],
#  ['unresectable',
#   'extrahepatic bile duct cancer',
#   'gallbladder cancer',
#   'biliary tract cancer'],
#  ['prostatic adenocarcinoma', 'prostate cancer'],
#  ['luad', 'lung cancer', 'lung adenocarcinoma'],
#  ['colorectal carcinoma', 'colorectal cancer'],
#  ['head neck carcinoma', 'hnscc'],
#  ['pancreatic cancer'],
#  ['head neck cancer',
#   'anogenital cancer',
#   'anal cancer',
#   'oropharyngeal cancer',
#   'hpv positive hnc cancer',
#   'hncs',
#   'cervical cancer',
#   'hpv associated cancer'],
#  ['ilc', 'pleomorphic invasive lobular carcinoma'],
#  ['aml'],
#  ['head neck carcinoma', 'gastric cancer', 'lung cancer', 'melanoma'],
#  ['intrahepatic cholangiocarcinoma'],
#  ['metastatic colorectal cancer', 'mcolorectal cancer'],
#  [],
#  ['colorectal cancer'],
#  ['colorectal cancer'],
#  [],
#  ['testicular cancer'],
#  [],
#  ['endometrial carcinoma', 'endometrial cancer'],
#  ['xlf mri'],
#  ['hnscc'],
#  ['ptc'],
#  [],
#  ['lung cancer'],
#  [],
#  [],
#  ['leiomyosarcomas', 'leiomyosarcoma'],
#  [],
#  ['glioblastoma multiforme', 'gbm', 'anaplastic astrocytoma'],
#  ['breast cancer'],
#  ['merkel s carcinoma'],
#  ['immunodeficiencies'],
#  ['colorectal cancer', 'upper gi cancer'],
#  ['npc'],
#  ['glioma', 'glioblastoma'],
#  ['gastric cancer', 'dlbcl'],
#  ['breast cancer'],
#  ['scc', 'ocular malignancy', 'eyelid scc', 'limbal scc'],
#  [],
#  ['lung cancer', 'adenocarcinoma'],
#  ['mibc', 'bladder cancer'],
#  ['lung cancer', 'cancer'],
#  ['ependymomas'],
#  [],
#  ['acute leukemia',
#   'aml',
#   'acute lymphoblastic leukemia all',
#   'acute lymphoblastic leukemia',
#   'all'],
#  ['medulloblastoma', 'intracranial xenograft', 'mycamp  mb'],
#  ['olaparib radiosensitized', 'pancreatic cancer'],
#  ['soft sarcomas', 'gist'],
#  ['urothelial cancer', 'bladder cancer'],
#  ['ccolorectal cancerc', 'ccolorectal cancercs', 'tcga pancancer'],
#  [],
#  ['gastric cancer', 'platinum sensitive ovarian cancer'],
#  ['prostate cancer'],
#  ['induced liver'],
#  ['breast cancer', 'basal like breast cancer'],
#  ['bladder cancer'],
#  ['colorectal cancer'],
#  ['breast', 'prostate cancer'],
#  ['pancreatic cancer', 'pancreatic sections', 'pancreatic'],
#  ['breast ovarian cancer', 'breast cancer'],
#  ['hodgkin s lymphoma', 'testicular cancer', 'hodgkin lymphoma'],
#  [],
#  ['colon cancer'],
#  ['metastatic triple negative breast cancer',
#   'breast cancer',
#   'mtriple negative breast cancer'],
#  ['endometrioid',
#   'uterine cancer',
#   'endometrioid endometrial cancer',
#   'endometrial cancer'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['endometrial cancer'],
#  ['hcc'],
#  ['hcc', 'pancreatic cancer'],
#  ['breast cancer'],
#  ['head neck carcinoma', 'hnsccs', 'hnscc'],
#  ['colorectal cancer'],
#  ['scc', 'non melanoma skin cancer', 'nmsc', 'nmscs', 'sccs'],
#  [],
#  ['kidney renal',
#   'escc',
#   'kirc',
#   'colon adenocarcinoma',
#   'esophageal carcinoma'],
#  ['epithelial ovarian cancer', 'eoc', 'ovarian cancer'],
#  ['biliary tract cancer'],
#  ['breast cancer', 'triple negative breast cancer', 'metabric'],
#  [],
#  ['colorectal cancer'],
#  ['scc'],
#  ['endometrial carcinoma', 'nsmp subtype cancer', 'endometrial cancer'],
#  ['braf melanomas', 'melanoma', 'melanomas'],
#  ['glioma', 'gbm', 'glioblastoma', 'malignant cancer'],
#  ['msi'],
#  ['luad', 'lung adenocarcinoma'],
#  ['breast cancer', 'triple negative breast cancer'],
#  ['solid malignancies'],
#  [],
#  ['sarcoma', 'renal mrts'],
#  [],
#  ['left kidney', 'proximal gastric cancer'],
#  ['lymphomas', 'colon cancer'],
#  ['malignant gliomas',
#   'diffuse idh mutant astrocytoma',
#   'colon cancer',
#   'idh mutant gliomas',
#   'idh mutant astrocytoma',
#   'idh mutant astrocytomas'],
#  ['dmmr cancer', 'prostate cancer', 'histologies'],
#  ['hgg'],
#  ['cancer histologies'],
#  ['mcrpc', 'prostate cancer'],
#  [],
#  ['metastatic cancer', 'colon cancer'],
#  ['hcc'],
#  ['hcc', 'digestive cancer'],
#  ['brd'],
#  ['melanoma'],
#  ['malignancy'],
#  ['melanoma', 'skin cancer'],
#  [],
#  ['colorectal cancer', 'metastatic colorectal cancer'],
#  ['triple negative breast cancer'],
#  ['hematologic malignancies',
#   'leukemia',
#   'sporadic leukemia',
#   'leukemias',
#   'non skin cancer',
#   'sarcomas'],
#  [],
#  [],
#  [],
#  ['mec', 'accc', 'adenoid cystic carcinoma', 'mucoepidermoid carcinoma'],
#  ['glioblastoma'],
#  ['oral cancer'],
#  ['intrahepatic cholangiocarcinoma'],
#  ['hepatomas'],
#  [],
#  [],
#  ['colorectal cancer', 'small bowel adenocarcinoma'],
#  ['osteosarcoma', 'osteosarcomas'],
#  ['triple negative breast cancer'],
#  ['gi cancer',
#   'ovarian cancer',
#   'pancreatic cancer',
#   'gastrointestinal cancer',
#   'breast'],
#  [],
#  ['triple negative breast cancer'],
#  ['breast cancer'],
#  ['colon cancer', 'tcga colon cancer'],
#  ['pan cancer', 'ccle', 'breast cancer'],
#  ['breast', 'ovarian', 'pancreatic cancer'],
#  ['hematologic', 'solid cancer'],
#  ['cll', 'chronic lymphocytic leukemia'],
#  ['colorectal cancer'],
#  [],
#  ['adenocarcinoma lung cancer', 'lung cancer'],
#  ['prostate cancer'],
#  [],
#  ['luad', 'lung adenocarcinoma'],
#  ['tets', 'thymomas'],
#  [],
#  ['mcl', 'mcls'],
#  ['head neck cancer', 'oscc', 'oral carcinoma', 'malignant disease'],
#  ['cervical cancer'],
#  ['ependymomas'],
#  ['adrenocortical carcinoma',
#   'adrenal cortical carcinoma',
#   'endometrial cancer'],
#  ['breast cancer'],
#  [],
#  ['breast cancer'],
#  ['hcc', 'non alcoholic steatohepatitis associated hcc', 'achilles heel'],
#  ['sarcoma',
#   'uterine leiomyosarcoma',
#   'ovarian',
#   'pancreatic cancer',
#   'oral small molecule',
#   'sarcomas'],
#  ['esophageal carcinoma', 'esophageal carcinoma escc'],
#  ['organ confined prostate cancer', 'prostate cancer'],
#  ['biliary tract cancer'],
#  ['glioblastoma multiforme', 'gbm'],
#  ['er breast cancer', 'breast cancer'],
#  ['escc', 'esophageal cancer'],
#  ['metastatic prostate cancer', 'prostate cancer'],
#  ['leukemia', 'hematopoietic disorders'],
#  ['rectum adenocarcinoma',
#   'colon adenocarcinoma',
#   'coad',
#   'colorectal cancer'],
#  ['endometrioid', 'endometrial cancer'],
#  ['hgsc', 'ovarian cancer'],
#  ['esophageal carcinoma',
#   'esophageal cancer',
#   'aerodigestive tract carcinoma'],
#  ['ganglioneuroblastoma', 'neuroblastoma'],
#  ['hbv induced liver'],
#  ['prostate cancer'],
#  [],
#  ['breast cancer'],
#  ['polzeta'],
#  ['aml', 'acute myeloid leukemia'],
#  ['acute promyelocytic leukemia', 'apl'],
#  ['skcm', 'skin cutaneous melanoma'],
#  ['ovarian cancer', 'platinum sensitive cancer', 'hgsc'],
#  ['ovarian', 'breast cancer', 'prostate cancer'],
#  ['gbm', 'glioblastoma'],
#  ['gastric cancer', 'lung cancer'],
#  ['gastric cancertb', 'neoplasms', 'chondroblastomas', 'bone cancer'],
#  ['oscc', 'oral cancer', 'oral carcinoma'],
#  ['lgg'],
#  ['notch driven'],
#  ['blbc',
#   'breast cancer',
#   'basal like breast cancer',
#   'luminal breast cancer'],
#  ['prostate cancer plasma', 'prostate cancer'],
#  ['argarg'],
#  ['breast cancer'],
#  ['ovarian', 'breast cancer', 'prostate cancer', 'pancreatic'],
#  ['lower cancer'],
#  ['leukemia'],
#  ['crypt proliferation hyperplasia'],
#  [],
#  ['colorectal cancer', 'pancreatic cancer'],
#  ['gastric cancer', 'gastrointestinal', 'gi cancer', 'gastric cancer'],
#  ['ccolorectal cancerc'],
#  [],
#  ['oscc', 'oral carcinoma'],
#  [],
#  ['pdac',
#   'pancreatic cancer',
#   'loxo',
#   'tcc',
#   'axonal cancer',
#   'pancreatic ductal adenocarcinoma'],
#  ['cervical cancer',
#   'gynecological malignancies',
#   'gynecological cancer',
#   'endometrial cancer'],
#  [],
#  ['solid organ cancer', 'myeloma', 'blood cancer'],
#  ['somatic cancer', 'ascc'],
#  ['glioblastoma multiforme', 'gbm'],
#  ['breast cancer'],
#  ['colorectal cancer'],
#  ['hpv negative hnscc',
#   'head neck carcinoma',
#   'hpv positive head neck cancer',
#   'hpv positive hnscc',
#   'hpv induced hnscc',
#   'hnscc'],
#  ['invasive ductal carcinoma', 'idc', 'breast cancer'],
#  ['sbc', 'small bowel carcinoma'],
#  ['sclc'],
#  ['ovarian carcinoma', 'ovarian cancer'],
#  ['hpv negative hnscc', 'head neck carcinoma', 'hnscc'],
#  ['cervical cancer'],
#  ['breast cancer', 'ccnd'],
#  ['glioma'],
#  ['glioblastoma multiforme', 'gbm', 'brain cancer'],
#  ['crpc', 'prostate cancer'],
#  ['platinum based cancer'],
#  ['na based cancer'],
#  ['gbm', 'glioblastoma'],
#  [],
#  ['triplenegative breast cancer',
#   'breast cancer',
#   'triple negative breast cancer'],
#  ['glioblastoma'],
#  ['luad', 'lung adenocarcinoma'],
#  ['mucosal cancer', 'biogrid'],
#  ['lung cancer'],
#  [],
#  ['mcrpc', 'prostate cancer'],
#  ['colorectal cancer'],
#  ['gist', 'gists', 'epithelioid'],
#  ['gbm', 'glioblastoma', 'gbm cancer'],
#  ['gbm', 'glioblastoma'],
#  ['myeloma', 'blood cancer'],
#  [],
#  ['mcrpc', 'prostate cancer'],
#  ['pdac', 'pancreatic ductal adenocarcinoma', 'pdacs'],
#  ['hcc'],
#  ['crpc', 'prostate cancer'],
#  ['melanoma'],
#  [],
#  ['super enhancer', 'prostate cancer'],
#  ['syndrome induced cancer'],
#  ['ccrt', 'rectal cancer'],
#  ['glioblastomas', 'glioblastoma', 'formalin fixed paraffin'],
#  [],
#  [],
#  ['prostate cancer'],
#  ['pontine glioma', 'dipg'],
#  ['prostate cancer'],
#  ['prostate cancer'],
#  [],
#  [],
#  ['prostate cancer'],
#  ['head neck cancer', 'solid cancer', 'ovarian'],
#  ['kidney renal',
#   'kirc',
#   'pancreatic adenocarcinoma',
#   'adrenocortical carcinoma',
#   'prostate adenocarcinoma',
#   'colon adenocarcinoma',
#   'breast invasive carcinoma'],
#  ['breast cancer'],
#  ['urothelial cancer'],
#  ['head neck carcinoma', 'hnscc'],
#  ['breast cancer',
#   'triple negative breast cancer',
#   'triple negative breast cancer'],
#  ['liver cancer'],
#  ['colorectal cancer'],
#  ['pdac', 'pancreatic ductal adenocarcinoma'],
#  ['oral olaparib',
#   'endometrioid carcinoma',
#   'relapsed platinum sensitive ovarian cancer',
#   'peritoneal cancer'],
#  ['head neck carcinoma', 'hnscc'],
#  ['cervical cancer'],
#  ['gastric cancer'],
#  ['prostate pdes', 'prostate cancer'],
#  ['gastric cancer'],
#  ['metastatic pancreas cancer',
#   'pancreatic malignancies',
#   'pancreatic cancer'],
#  ['colorectal cancer'],
#  ['pdac', 'pancreatic adenocarcinoma'],
#  ['pdac', 'pancreatic ductal adenocarcinoma', 'pancreatic cancer'],
#  ['prostate malignancies',
#   'ovarian cancer',
#   'pancreatic cancer',
#   'breast cancer',
#   'prostate cancer',
#   'pancreatic'],
#  ['breast cancer'],
#  ['breast cancer', 'tcga breast cancer'],
#  [],
#  ['hematologic cancer', 'breast cancer', 'triple negative breast cancer'],
#  ['epithelial ovarian cancer', 'ovarian cancer'],
#  ['head', 'keratinocyte cancer', 'leg skin', 'skin cancer'],
#  [],
#  ['angiosarcoma', 'angiosarcomas', 'skin cancer'],
#  ['colorectal cancer'],
#  ['breast cancer'],
#  [],
#  ['hcc'],
#  ['ovarian cancer', 'ovarian', 'ovca'],
#  ['endometrioid',
#   'ovarian',
#   'epithelial ovarian cancer',
#   'breast cancer',
#   'eoc',
#   'histotypes'],
#  ['ovarian cancer'],
#  ['luad', 'lung adenocarcinoma', 'lusc', 'lung carcinoma'],
#  ['prostate cancer'],
#  [],
#  ['endometrial cancer'],
#  ['hsct', 'hematologic malignancies', 'malignancy', 'non hodgkin lymphomas'],
#  ['head neck cancer', 'precancerous lesions', 'hnc', 'head neck'],
#  ['colorectal cancer'],
#  [],
#  [],
#  ['neoplasia'],
#  ['nbsp ovarian cancer'],
#  [],
#  ['colorectal cancer'],
#  ['nasopharyngeal carcinoma', 'npc', 'epithelial malignancy'],
#  ['ipf'],
#  ['lung cancer'],
#  ['glioblastoma multiforme',
#   'head neck carcinoma',
#   'acute myeloid leukemialymphoma',
#   'cik',
#   'uveal melanoma',
#   'breast invasive carcinoma'],
#  ['pdac', 'pancreatic ductal adenocarcinoma', 'pancreatic cancer'],
#  ['prostate cancer'],
#  ['glioma', 'glioblastomas'],
#  ['rcc', 'birt hogg dube'],
#  ['sclc'],
#  ['mcolorectal cancer'],
#  ['colorectal cancer'],
#  ['a'],
#  ['myeloma'],
#  ['repair based cancer'],
#  ['cin'],
#  ['gastric cancer', 'hpe'],
#  ['endometrial cancer'],
#  ['ccolorectal cancerc'],
#  ['radiation induced lung'],
#  ['escc', 'lung cancer', 'esophageal carcinoma'],
#  ['tcga', 'prostate cancer'],
#  ['breast cancer'],
#  ['somatic breast cancer', 'ovarian cancer'],
#  [],
#  [],
#  ['colorectal cancer'],
#  ['lung adenocarcinoma'],
#  ['bladder cancer', 'head neck'],
#  ['myeloma', 'haematological cancer'],
#  ['head neck cancer', 'oral cavity cancer', 'hnc'],
#  ['aml', 'acute myeloid leukemia'],
#  [],
#  ['luad', 'lung adenocarcinoma'],
#  [],
#  ['ankl'],
#  [],
#  [],
#  ['breast cancer'],
#  ['alt cancer'],
#  ['low tmb cancer',
#   'small intestine cancer',
#   'braf mutant colorectal cancer',
#   'colorectal cancer',
#   'endometrial cancer'],
#  ['malignant diseases'],
#  [],
#  [],
#  ['prostate cancer',
#   'ovarian',
#   'mcrpc',
#   'pancreatic',
#   'prostate cancer',
#   'parpis'],
#  ['colorectal cancer'],
#  ['triple negative breast cancer'],
#  [],
#  ['endometrial cancer'],
#  ['oesophageal cancer'],
#  ['urothelial carcinoma'],
#  ['kalrn wildtype cancer'],
#  ['prostate cancer'],
#  ['cn aml', 'acute myeloid leukemias'],
#  ['breast cancer'],
#  ['colorectal cancer', 'colorectal cancer'],
#  [],
#  ['yrpd'],
#  ['gbm', 'cadherin', 'glioblastoma'],
#  ['lung adenocarcinoma'],
#  ['dmmr lung cancer', 'dmmr cancer'],
#  ['pdac', 'pancreatic ductal adenocarcinoma', 'pancreatic adenocarcinoma'],
#  ['stereotactic body'],
#  ['colorectal cancer'],
#  ['myeloma'],
#  ['cervical cancer'],
#  ['endometrial cancer'],
#  ['prostatic intraepithelial neoplasia',
#   'prostate adenocarcinoma',
#   'prostate cancer'],
#  ['hyperphagia induced'],
#  ['prostate cancer'],
#  ['mbc',
#   'metaplastic breast carcinoma',
#   'metaplastic breast cancer',
#   'uterine carcinosarcomas',
#   'adenocarcinoma'],
#  ['enoc', 'endometrioid ovarian carcinoma'],
#  [],
#  ['hcc'],
#  ['head neck carcinoma'],
#  ['breast cancer'],
#  ['precancerous lesions',
#   'endometrial atypical hyperplasia',
#   'endometrial intraepithelial neoplasia',
#   'endometrial carcinoma',
#   'uterine endometrioid carcinoma'],
#  ['breast', 'ovarian cancer'],
#  ['ovarian cancer'],
#  ['hnscc', 'head neck carcinoma'],
#  ['ovarian cancer'],
#  ['pregnancy associated breast cancer', 'breast cancer'],
#  ['neuroblastoma'],
#  ['breast cancer'],
#  [],
#  ['ovarian cancer'],
#  ['mammary gl', 'ggtt'],
#  ['breast cancer', 'somatic mouth carcinoma'],
#  ['oxidative lesions'],
#  ['msi', 'colorectal cancer', 'endometrial cancer'],
#  ['breast cancer'],
#  ['lung cancer', 'breast cancer', 'ipsilateral lung cancer'],
#  [],
#  ['prostate cancer'],
#  [],
#  ['radiation induced tgfbeta', 'breast cancer'],
#  ['colorectal cancer'],
#  ['prostate cancer'],
#  [],
#  ['ovarian'],
#  ['benign sebaceous neoplasm'],
#  ['colorectal cancer', 'colorectal cancer'],
#  ['bcbm', 'breast cancer brain'],
#  ['nmibc', 'bladder cancer'],
#  ['nasopharyngeal carcinoma', 'npc'],
#  ['hpv positive', 'hnscc', 'head neck carcinoma'],
#  ['ovarian cancer', 'peritoneal carcinoma', 'hgsc', 'hgscs'],
#  ['breast cancer'],
#  ['post transplant lymphoproliferative disorders lymphomas',
#   'lymphomas',
#   'burkitt lymphoma'],
#  ['msi', 'breast cancer', 'ovarian cancer'],
#  ['breast cancer'],
#  ['neoplasia', 'colorectal cancer', 'colorectal cancer'],
#  [],
#  ['endometrial cancer'],
#  ['hgsoc'],
#  ['mcrpc', 'prostate cancer'],
#  ['breast cancer'],
#  ['esophageal cancer', 'neoplasms'],
#  ['uterine corpus endometrial cancer', 'ucec'],
#  [],
#  ['fm hcr', 'breast cancer', 'triple negative breast cancer'],
#  ['ovarian cancer'],
#  ['nasopharyngeal carcinoma'],
#  ['sarcoma'],
#  ['lung cancer'],
#  ['melanoma'],
#  ['colorectal cancer'],
#  ['colorectal adenocarcinoma', 'gastric', 'ovarian cancer', 'breast'],
#  ['colorectal cancer', 'mucinous carcinoma'],
#  ['platinum sensitive', 'ovarian cancer'],
#  ['b lymphoid malignancies'],
#  [],
#  [],
#  ['ipf'],
#  ['dmmr colorectal cancer',
#   'gastric cancer',
#   'cancer center',
#   'colorectal cancer',
#   'colorectal cancer'],
#  ['breast', 'ovarian cancer'],
#  [],
#  ['neoplasms', 'ovarian', 'ovarian cancer'],
#  [],
#  ['osteosarcoma', 'ataxia telangiectasia'],
#  ['extra colorectal cancer',
#   'colorectal cancer',
#   'metachronous colorectal cancer',
#   'lynch like'],
#  ['breast cancer', 'luminal breast cancer'],
#  ['stomach adenocarcinoma'],
#  ['hematologic neoplasms', 'leukemia', 'hematologic malignancies'],
#  ['hcc'],
#  ['melanoma'],
#  ['colorectal carcinoma', 'colorectal cancer'],
#  ['esophageal adenocarcinoma', 'eac'],
#  [],
#  ['breast cancer'],
#  ['hgsoc'],
#  ['pdac',
#   'ipmns',
#   'cystic precursor lesions',
#   'intraductal papillary mucinous neoplasms',
#   'pancreatic'],
#  [],
#  ['mcrpc'],
#  ['hcc', 'chemo naive'],
#  ['mcrpc', 'prostate cancer'],
#  ['breast cancer', 'prostate cancer'],
#  ['ovarian cancer', 'breast', 'non cancer'],
#  ['solid malignancies'],
#  ['ehrlich ascites carcinoma'],
#  ['msi cancer', 'msi colorectal', 'endometrial cancer'],
#  ['loco regional', 'oligometastatic disease', 'endometrial cancer'],
#  ['nonmalignant'],
#  ['breast ovarian cancer', 'pancreatic cancer'],
#  ['thyroid cancer', 'well differentiated thyroid cancer'],
#  ['colorectal cancer'],
#  ['colon adenocarcinoma'],
#  ['glioblastoma'],
#  ['metastatic urothelial cancer',
#   'crpc',
#   'urothelial carcinoma',
#   'prostate cancer',
#   'eau',
#   'metastatic kidney cancer',
#   'prostate cancer',
#   'bladder cancer'],
#  ['pdac', 'pancreatic ductal adenocarcinoma', 'pancreatic cancer'],
#  ['er breast cancer', 'breast cancer'],
#  ['cleft palate',
#   'colorectal carcinoma',
#   'pancreatic ductal adenocarcinoma',
#   'lung adenocarcinoma'],
#  ['super enhancer'],
#  ['aml', 'acute myeloid leukemia'],
#  ['opscc', 'hpv opscc', 'hpv', 'hpv', 'oropharyngeal carcinoma'],
#  ['nhl', 'non hodgkin lymphoma', 'mcl'],
#  ['colorectal cancer'],
#  ['adenoma carcinoma',
#   'colitis associated cancer',
#   'colon cancer',
#   'inflammation dysplasia carcinoma',
#   'colorectal cancer'],
#  ['prostate hyperplasia', 'prostate adenocarcinoma', 'prostate cancer'],
#  ['cervical cancer', 'cervical carcinoma'],
#  ['ovarian cancer', 'breast cancer'],
#  ['lung cancer'],
#  ['colorectal cancer', 'endometrioid', 'endometrial cancer'],
#  ['formalin fixed paraffin embedded', 'lung cancer', 'lung adenocarcinoma'],
#  ['thyroid cancer'],
#  ['anaplastic gliomas', 'hgg', 'idh mut gliomas'],
#  ['head neck carcinoma', 'hnscc', 'hnsccs'],
#  ['gynecological malignancies', 'ovarian cancer'],
#  ['mmrd',
#   'pancreatic cancer',
#   'pancreatic adenocarcinoma',
#   'unresectable mmrd cancer',
#   'mmrd pancreatic cancer',
#   'mmrd cancer'],
#  [],
#  ['colorectal carcinoma', 'colorectal cancer'],
#  ['gliomas', 'glioblastomas', 'brain cancer'],
#  ['colorectal cancer', 'radiosensitized colorectal cancer'],
#  ['breast cancer', 'triple negative breast cancer'],
#  ['lung cancer', 'adenocarcinoma'],
#  ['cervical cancer', 'head neck'],
#  ['radiation induced lymphoma'],
#  ['luad', 'lung cancer', 'lung adenocarcinoma'],
#  ['cutaneous head neck cutaneous carcinoma',
#   'metachronous malignancies',
#   'hncscc',
#   'cutaneous head neck carcinoma'],
#  [],
#  ['neoplasm risk',
#   'sarcoma',
#   'thyroid cancer',
#   'bcc',
#   'breast cancer',
#   'meningioma'],
#  ['metastatic prostate cancer',
#   'breast cancer',
#   'metastatic pc',
#   'prostate cancer'],
#  ['formalin fixed paraffin embedded',
#   'biliary cancer',
#   'intrahepatic cholangiocarcinoma'],
#  ['mcrpc', 'prostate cancer'],
#  ['hcc', 'ahntu'],
#  ['colon cancer'],
#  ['bladder cancer'],
#  ['non skin cancer', 'prostate cancer'],
#  ['malignant cancer'],
#  ['bone sarcomas',
#   'breast cancer',
#   'thyroid carcinoma',
#   'meningioma',
#   'melanoma'],
#  ['scc', 'bcc', 'nmsc', 'nonmelanoma skin cancer'],
#  ['keratinocyte carcinoma', 'melanomas'],
#  ['scc', 'bcc', 'epidermal cancer', 'nonmelanoma skin cancer'],
#  [],
#  ['keratinocyte derived neoplasms', 'non melanoma skin cancer'],
#  ['mbc', 'colorectal cancer', 'breast cancer'],
#  ['endometrioid', 'ovarian cancer'],
#  ['malignant pleural mesothelioma', 'mpm'],
#  ['colorectal cancer', 'colon cancer'],
#  ['ovarian cancer'],
#  ['mcrpc'],
#  ['acute lymphoblastic leukemia', 'myeloma'],
#  ['kidney renal',
#   'ucec',
#   'kirc',
#   'adrenocortical carcinoma',
#   'lung adenocarcinoma',
#   'thymoma',
#   'luad',
#   'uterine corpus endometrial carcinoma'],
#  ['colorectal cancer', 'pmr'],
#  ['ovarian cancer', 'endometrial cancer'],
#  ['hcc'],
#  ['endometrial carcinoma'],
#  ['lung cancer'],
#  ['breast cancer',
#   'endometrial carcinoma',
#   'bilateral breast carcinoma',
#   'endometrial cancer'],
#  ['ewing sarcoma'],
#  ['neuroendocrine non neuroendocrine neoplasms'],
#  [],
#  ['bladder', 'bca', 'bladder cancer'],
#  ['breast cancer'],
#  ['breast cancer'],
#  [],
#  ['cml', 'breast cancer'],
#  ['loco regional',
#   'otscc',
#   'oral tongue',
#   'llscc',
#   'oral tongue carcinoma',
#   'lower lip carcinoma'],
#  ['adult malignancies', 'medulloblastoma'],
#  ['aml', 'acute myeloid leukemia'],
#  ['melanoma'],
#  ['inoperable lung cancer', 'lung cancer'],
#  ['ampullary carcinoma',
#   'gbc',
#   'cholangiocarcinoma',
#   'gallbladder cancer',
#   'extrahepatic cholangiocarcinoma',
#   'biliary tract cancer'],
#  ['prostate cancer'],
#  ['hgg'],
#  ['ovarian carcinoma', 'ovarian cancer'],
#  [],
#  [],
#  ['carcinogen induced cancer'],
#  ['sts'],
#  ['breast cancer'],
#  ['lung cancer'],
#  ['breast cancer', 'ovarian cancer'],
#  [],
#  [],
#  ['glioma', 'gliomas'],
#  ['breast cancer'],
#  ['gbm', 'glioblastoma'],
#  ['prostate cancer'],
#  ['gliomas', 'glioblastoma'],
#  ['ovarian cancer', 'ovarian', 'peritoneal cancer'],
#  ['breast cancer', 'cervical cancer', 'colorectal cancer'],
#  ['manec',
#   'gastroesophageal manec',
#   'adenoneuroendocrine carcinoma',
#   'gastrointestinal tract'],
#  ['prostate cancer'],
#  ['btc', 'biliary tract cancer'],
#  ['malignant mesothelioma', 'uveal melanoma', 'cutaneous melanoma'],
#  [],
#  [],
#  [],
#  [],
#  ['pdac', 'pancreatic ductal adenocarcinoma', 'pancreatic cancer'],
#  ['hccs', 'fss', 'hcc'],
#  ['colorectal cancer', 'colorectal cancer'],
#  ['oropharyngeal carcinoma'],
#  ['gastric cancer', 'metastatic lesions', 'mgastric cancer'],
#  ['aml', 'acute myeloid leukemia'],
#  ['anaplastic astrocytoma'],
#  ['colorectal cancer', 'colorectal cancer ras', 'mcolorectal cancer'],
#  [],
#  ['liver homogenate'],
#  [],
#  ['head neck cancer'],
#  ['rca driven'],
#  ['sts', 'soft sarcomas'],
#  ['radiation induced cancer'],
#  ['breast cancer', 'negative', 'negative breast cancer'],
#  ['lung cancer'],
#  [],
#  [],
#  ['acs',
#   'ampullary carcinoma',
#   'colon cancer',
#   'ampullary cancer',
#   'colorectal cancer',
#   'medullary carcinoma'],
#  [],
#  ['parpi', 'mcrpc', 'metastatic prostate cancer'],
#  ['pdac',
#   'pancreatic cancer',
#   'pancreas cancer olaparib',
#   'pancreatic ductal adenocarcinoma'],
#  ['breast cancer', 'triple negative breast cancer'],
#  ['rms', 'rhabdomyosarcoma'],
#  ['gynecological cancer'],
#  ['aml', 'acute myeloid leukemia'],
#  ['breast cancer'],
#  ['sjogren'],
#  ['prostate cancer'],
#  ['embryonal carcinoma', 'tgastric cancerts'],
#  [],
#  ['colon cancer'],
#  [],
#  [],
#  ['ovarian carcinoma'],
#  ['neuroblastoma uk', 'interpretation', 'neuroblastoma'],
#  ['laparoscopic colon cancer'],
#  ['mcrpc'],
#  ['liver cancer'],
#  ['lynch like', 'endometrial cancer'],
#  ['pancreatic ductal adenocarcinoma',
#   'mediastinal lymphadenopathy',
#   'braf mek'],
#  ['skin cancer', 'melanomas'],
#  ['malignant pleural mesothelioma', 'mpm'],
#  ['breast cancer', 'ran ip'],
#  ['glioblastoma multiforme', 'breast cancer', 'triple negative breast cancer'],
#  ['lynch like', 'colorectal cancer'],
#  ['sae'],
#  ['leukemia'],
#  ['hpv hnsccs', 'head neck carcinoma', 'hpv', 'hnsccs'],
#  ['breast cancer'],
#  ['uterine cancer', 'endometrial cancer'],
#  [],
#  ['gynaecological malignancy', 'ovarian cancer'],
#  ['prostate cancer'],
#  ['parpi cancer'],
#  ['pgi dlbcl', 'non hodgkin lymphoma'],
#  ['escc', 'esophageal carcinoma'],
#  ['endometrial cancer'],
#  ['eoc',
#   'breast',
#   'epithelial tubo ovarian carcinoma',
#   'hgsoc',
#   'epithelial ovarian carcinoma'],
#  ['ber ssbr'],
#  ['skin cancer'],
#  ['head neck carcinoma', 'cancer'],
#  ['metastatic colorectal cancer', 'mcolorectal cancer'],
#  ['melanoma'],
#  [],
#  [],
#  ['colon cancer', 'msi h cancer', 'colorectal cancer'],
#  ['gastric cancer',
#   'benign',
#   'gastrointestinal cancer',
#   'colorectal adenomas',
#   'cervical cancer',
#   'extraintestinal cancer',
#   'colorectal cancer',
#   'non cancer'],
#  [],
#  ['breast cancer'],
#  ['breast cancer', 'ovarian cancer'],
#  ['hematologic', 'ovarian cancer'],
#  ['breast cancer'],
#  ['breast', 'parpi'],
#  ['gastric cancer', 'gastrointestinal cancer'],
#  [],
#  ['lung cancer'],
#  [],
#  ['pscc', 'penile carcinoma', 'penile cancer', 'locoregional pscc'],
#  ['colorectal cancer', 'metastatic colorectal cancer', 'mcolorectal cancer'],
#  ['esophageal cancer'],
#  ['lung adenocarcinoma'],
#  ...]

# %%
records = []
for i in range(0,len(gene)):
    records.append([gene[i],cancer[i]])
data = [flatten(x) for x in records]

# %% [markdown]
# # Apriori Algorithm

# %%
association_rules = apriori(data, min_support=0.004, min_confidence=0.3, min_lift=5, min_length=2)
association_results = list(association_rules)

# %%
len(association_results)
# Out:
# 157

# %% [markdown]
# ### Display Rule, Suuport and confidence

# %%
table= {'Entity1':[],'Entity2':[],'Rule':[],'Support':[],'Confidence':[],'Lift':[]}
for item in association_results:
    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])
    table['Rule'].append(items[0] + " -> " + items[1])
    table['Entity1'].append(items[0])
    table['Entity2'].append(items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))
    table['Support'].append(item[1])
    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    table['Confidence'].append(item[2][0][2])
    table['Lift'].append(item[2][0][3])
    print("=====================================")
# Out:
# Rule: ATM -> ATR
# Support: 0.005197698162242435
# Confidence: 0.5511811023622047
# Lift: 12.402725975042593
# =====================================
# Rule: Arg280His -> Arg194Trp
# Support: 0.0042695377761277145
# Confidence: 0.41666666666666663
# Lift: 83.13271604938271
# =====================================
# Rule: Arg399Gln -> Arg194Trp
# Support: 0.008130684982364952
# Confidence: 0.7934782608695652
# Lift: 50.16980506225761
# =====================================
# Rule: XRCC1 -> Arg194Trp
# Support: 0.010135511416372749
# Confidence: 0.9891304347826085
# Lift: 23.2075159066808
# =====================================
# Rule: Arg280His -> Arg399Gln
# Support: 0.004380917022461481
# Confidence: 0.874074074074074
# Lift: 55.26569292296992
# =====================================
# Rule: Arg280His -> XRCC1
# Support: 0.004937813254130314
# Confidence: 0.9851851851851853
# Lift: 23.114950316169832
# =====================================
# Rule: Arg399Gln -> XRCC1
# Support: 0.015704473733061074
# Confidence: 0.9929577464788734
# Lift: 23.297314374049176
# =====================================
# Rule: BRAF -> KRAS
# Support: 0.00727677742713941
# Confidence: 0.3805825242718447
# Lift: 25.82113423491722
# =====================================
# Rule: BRCA2 -> BRCA1
# Support: 0.033673658808242066
# Confidence: 0.44157740993184036
# Lift: 8.662700317927253
# =====================================
# Rule: BRCA1 -> CHEK2
# Support: 0.004121032114349359
# Confidence: 0.5285714285714286
# Lift: 6.931388232021144
# =====================================
# Rule: BRCA1 -> PALB2
# Support: 0.005903100055689624
# Confidence: 0.6708860759493671
# Lift: 8.797622422442164
# =====================================
# Rule: BRCA1 -> breast
# Support: 0.006237237794690923
# Confidence: 0.4577656675749319
# Lift: 6.00288133209873
# =====================================
# Rule: ovarian-cancer -> BRCA1
# Support: 0.019936885093744198
# Confidence: 0.41403238242097146
# Lift: 5.429387643869945
# =====================================
# Rule: BRCA2 -> CHEK2
# Support: 0.0040839056989047705
# Confidence: 0.5238095238095238
# Lift: 10.275899143342698
# =====================================
# Rule: BRCA2 -> PALB2
# Support: 0.006608501949136811
# Confidence: 0.7510548523206751
# Lift: 14.733912925897585
# =====================================
# Rule: BRCA2 -> breast
# Support: 0.004529422684239837
# Confidence: 0.33242506811989103
# Lift: 6.52139053882685
# =====================================
# Rule: ER -> breast-cancer
# Support: 0.004752181176907369
# Confidence: 0.540084388185654
# Lift: 5.25928163260325
# =====================================
# Rule: ERCC1 -> ERCC2
# Support: 0.00504919250046408
# Confidence: 0.4459016393442623
# Lift: 11.76333071081068
# =====================================
# Rule: ERCC1 -> non-small-cell-lung-cancer
# Support: 0.008464822721366252
# Confidence: 0.30039525691699603
# Lift: 7.924726978510566
# =====================================
# Rule: IDH1 -> MGMT
# Support: 0.005234824577687024
# Confidence: 0.7230769230769231
# Lift: 11.531129024912328
# =====================================
# Rule: PD -> L1
# Support: 0.006979766103582699
# Confidence: 0.9842931937172774
# Lift: 105.20609989196376
# =====================================
# Rule: XPD -> Lys751Gln
# Support: 0.006831260441804344
# Confidence: 0.8070175438596491
# Lift: 40.031339859778356
# =====================================
# Rule: Lys751Gln -> XRCC1
# Support: 0.004046779283460182
# Confidence: 0.4780701754385965
# Lift: 11.216742313099822
# =====================================
# Rule: brain-tumor -> MGMT
# Support: 0.005123445331353258
# Confidence: 0.33093525179856115
# Lift: 5.277525759144017
# =====================================
# Rule: gbm -> MGMT
# Support: 0.010618154817152404
# Confidence: 0.5553398058252428
# Lift: 8.856173872056196
# =====================================
# Rule: MGMT -> glioblastoma
# Support: 0.016595507703731204
# Confidence: 0.5643939393939394
# Lift: 9.00056291153094
# =====================================
# Rule: glioblastoma-multiforme -> MGMT
# Support: 0.004900686838685725
# Confidence: 0.47826086956521735
# Lift: 7.626972481787525
# =====================================
# Rule: glioblastomas -> MGMT
# Support: 0.0058288472248004455
# Confidence: 0.5946969696969697
# Lift: 9.48381461147891
# =====================================
# Rule: MGMT -> gliomas
# Support: 0.004752181176907369
# Confidence: 0.4587813620071684
# Lift: 7.3163268121155
# =====================================
# Rule: MMR -> MLH1
# Support: 0.011286430295155003
# Confidence: 0.47278382581648526
# Lift: 6.981596682218767
# =====================================
# Rule: MSH2 -> MLH1
# Support: 0.04648227213662521
# Confidence: 0.6864035087719299
# Lift: 11.76847772678035
# =====================================
# Rule: MSH6 -> MLH1
# Support: 0.03333952106924076
# Confidence: 0.4923245614035088
# Lift: 11.776875720607023
# =====================================
# Rule: PMS2 -> MLH1
# Support: 0.027993317245219973
# Confidence: 0.4133771929824561
# Lift: 12.581146545742886
# =====================================
# Rule: colorectal-cancers -> MLH1
# Support: 0.004046779283460182
# Confidence: 0.36212624584717606
# Lift: 5.347516684152241
# =====================================
# Rule: endometrial-cancer -> MLH1
# Support: 0.009430109522925561
# Confidence: 0.46777163904235725
# Lift: 6.907581742108494
# =====================================
# Rule: hnpcc -> MLH1
# Support: 0.013476888806385744
# Confidence: 0.406494960806271
# Lift: 6.002709303353569
# =====================================
# Rule: MSH2 -> MMR
# Support: 0.010655281232596993
# Confidence: 0.4463452566096423
# Lift: 7.652647668224517
# =====================================
# Rule: MMR -> MSH6
# Support: 0.008613328383144608
# Confidence: 0.36080870917573876
# Lift: 8.630890392227819
# =====================================
# Rule: MSH2 -> MSH6
# Support: 0.034156302209021716
# Confidence: 0.5856142584341183
# Lift: 14.008454752151843
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.02502320400965287
# Confidence: 0.4290260980267346
# Lift: 13.057421412824967
# =====================================
# Rule: endometrial-cancer -> MSH2
# Support: 0.007610915166140709
# Confidence: 0.3775322283609576
# Lift: 6.472839319479563
# =====================================
# Rule: MSH2 -> hnpcc
# Support: 0.01325413031371821
# Confidence: 0.3997760358342665
# Lift: 6.8542123012068545
# =====================================
# Rule: PMS2 -> MSH6
# Support: 0.02465193985520698
# Confidence: 0.5896980461811723
# Lift: 17.947476693660875
# =====================================
# Rule: endometrial-cancer -> MSH6
# Support: 0.00694263968813811
# Confidence: 0.3443830570902394
# Lift: 8.23797303972078
# =====================================
# Rule: MSI -> msi
# Support: 0.007388156673473176
# Confidence: 0.40120967741935487
# Lift: 22.846897803996455
# =====================================
# Rule: NF -> kappaB
# Support: 0.006831260441804344
# Confidence: 0.8214285714285714
# Lift: 120.24553571428571
# =====================================
# Rule: Thr241Met -> XRCC3
# Support: 0.006274364210135512
# Confidence: 0.9883040935672516
# Lift: 55.69031539797892
# =====================================
# Rule: XPD -> XRCC1
# Support: 0.007796547243363653
# Confidence: 0.38674033149171266
# Lift: 9.073911871715401
# =====================================
# Rule: XRCC1 -> XRCC3
# Support: 0.007722294412474476
# Confidence: 0.4351464435146444
# Lift: 10.209642383333577
# =====================================
# Rule: aml -> acute-myeloid-leukemia
# Support: 0.006905513272693522
# Confidence: 0.6914498141263941
# Lift: 73.613441673891
# =====================================
# Rule: ovarian-cancer -> breast
# Support: 0.007462409504362354
# Confidence: 0.547683923705722
# Lift: 11.373836919825463
# =====================================
# Rule: breast-cancer -> breast-tumor
# Support: 0.0066456283645814
# Confidence: 0.7131474103585657
# Lift: 6.944550071586394
# =====================================
# Rule: breast-cancer -> triple-negative-breast-cancer
# Support: 0.007128271765361054
# Confidence: 0.6056782334384858
# Lift: 5.898027193660743
# =====================================
# Rule: colorectal-cancers -> colorectal-cancer
# Support: 0.010358269909040282
# Confidence: 0.9269102990033222
# Lift: 7.283059773528145
# =====================================
# Rule: colorectal-cancer -> colorectal-tumor
# Support: 0.007351030258028587
# Confidence: 0.7586206896551724
# Lift: 5.960749205327324
# =====================================
# Rule: colorectal-cancer -> hnpcc
# Support: 0.029218488954891406
# Confidence: 0.8812989921612542
# Lift: 6.924675715829458
# =====================================
# Rule: escc -> esophageal-carcinoma
# Support: 0.004640801930573603
# Confidence: 0.880281690140845
# Lift: 132.46026437957352
# =====================================
# Rule: gbm -> glioblastoma
# Support: 0.010989418971598292
# Confidence: 0.5747572815533981
# Lift: 19.54682749828381
# =====================================
# Rule: gbm -> glioblastoma-multiforme
# Support: 0.007091145349916466
# Confidence: 0.370873786407767
# Lift: 36.19378781483045
# =====================================
# Rule: hMLH1 -> hMSH2
# Support: 0.022535734174865416
# Confidence: 0.6641137855579868
# Lift: 23.474940700793145
# =====================================
# Rule: hMSH6 -> hMLH1
# Support: 0.006385743456469278
# Confidence: 0.7350427350427351
# Lift: 21.661242963212327
# =====================================
# Rule: hMLH1 -> hPMS2
# Support: 0.005494709485799146
# Confidence: 0.9426751592356688
# Lift: 27.780038746184616
# =====================================
# Rule: hMSH6 -> hMSH2
# Support: 0.006979766103582699
# Confidence: 0.8034188034188033
# Lift: 28.399062296700087
# =====================================
# Rule: hPMS2 -> hMSH2
# Support: 0.004937813254130314
# Confidence: 0.8471337579617835
# Lift: 29.94428841299296
# =====================================
# Rule: hnpcc -> hMSH2
# Support: 0.009355856692036384
# Confidence: 0.3307086614173228
# Lift: 9.97495833737468
# =====================================
# Rule: hepatocellular-carcinoma -> hcc
# Support: 0.012697234082049378
# Confidence: 0.9047619047619048
# Lift: 49.532036391792495
# =====================================
# Rule: head-neck-carcinoma -> hnscc
# Support: 0.006757007610915166
# Confidence: 0.7811158798283262
# Lift: 91.87491800513523
# =====================================
# Rule: npc -> nasopharyngeal-carcinoma
# Support: 0.004380917022461481
# Confidence: 0.8368794326241135
# Lift: 165.74520233625364
# =====================================
# Rule: p21 -> p53
# Support: 0.00568034156302209
# Confidence: 0.5151515151515151
# Lift: 5.635908229328213
# =====================================
# Rule: p53 -> ras
# Support: 0.004121032114349359
# Confidence: 0.4703389830508474
# Lift: 5.145646022938496
# =====================================
# Rule: synthase -> thymidylate
# Support: 0.006237237794690923
# Confidence: 0.852791878172589
# Lift: 124.161887776101
# =====================================
# Rule: ATM -> BRCA2
# Support: 0.006088732132912568
# Confidence: 0.5674740484429066
# Lift: 11.132493441230654
# =====================================
# Rule: ATM -> breast-cancer
# Support: 0.00441804343790607
# Confidence: 0.5384615384615384
# Lift: 7.061081566923826
# =====================================
# Rule: Arg280His -> XRCC1
# Support: 0.0042695377761277145
# Confidence: 0.41666666666666663
# Lift: 84.38283208020049
# =====================================
# Rule: Arg399Gln -> XRCC1
# Support: 0.008130684982364952
# Confidence: 0.7934782608695652
# Lift: 50.5256192825573
# =====================================
# Rule: Arg280His -> Arg399Gln
# Support: 0.004343790607016893
# Confidence: 0.8666666666666667
# Lift: 55.1859732072498
# =====================================
# Rule: BRAF -> colorectal-cancer
# Support: 0.004603675515129014
# Confidence: 0.7167630057803467
# Lift: 5.631858681649253
# =====================================
# Rule: BRCA2 -> BRCA1
# Support: 0.005012066085019491
# Confidence: 0.569620253164557
# Lift: 16.915900241441392
# =====================================
# Rule: BRCA2 -> BRCA1
# Support: 0.007388156673473176
# Confidence: 0.5452054794520548
# Lift: 10.695636991289945
# =====================================
# Rule: RAD51 -> BRCA2
# Support: 0.004046779283460182
# Confidence: 0.4954545454545455
# Lift: 9.719641793021253
# =====================================
# Rule: breast-cancer -> BRCA2
# Support: 0.016484128457397437
# Confidence: 0.32337946103423154
# Lift: 9.48826338012748
# =====================================
# Rule: ovarian-cancer -> BRCA2
# Support: 0.010246890662706516
# Confidence: 0.30429988974641675
# Lift: 6.319442968635109
# =====================================
# Rule: breast-cancer -> PARP
# Support: 0.00441804343790607
# Confidence: 0.4219858156028369
# Lift: 5.533684490390658
# =====================================
# Rule: ovarian-cancer -> BRCA1
# Support: 0.004752181176907369
# Confidence: 0.34877384196185285
# Lift: 17.493898385926457
# =====================================
# Rule: ovarian-cancer -> breast-cancer
# Support: 0.007499535919806942
# Confidence: 0.6778523489932886
# Lift: 8.888974206491834
# =====================================
# Rule: ovarian-cancer -> BRCA2
# Support: 0.00504919250046408
# Confidence: 0.4563758389261745
# Lift: 8.953010357958128
# =====================================
# Rule: gbm -> MGMT
# Support: 0.006385743456469278
# Confidence: 0.3339805825242719
# Lift: 20.124758367541975
# =====================================
# Rule: MSH2 -> MMR
# Support: 0.009170224614813439
# Confidence: 0.38413685847589424
# Lift: 8.264158373041703
# =====================================
# Rule: MSH6 -> MMR
# Support: 0.007462409504362354
# Confidence: 0.312597200622084
# Lift: 9.376175499728099
# =====================================
# Rule: PMS2 -> MMR
# Support: 0.005977352886578801
# Confidence: 0.5296052631578947
# Lift: 16.11855114481118
# =====================================
# Rule: colorectal-cancer -> MMR
# Support: 0.006051605717467978
# Confidence: 0.5158227848101266
# Lift: 7.617152800910504
# =====================================
# Rule: MSH2 -> MSH6
# Support: 0.03092630406534249
# Confidence: 0.45668859649122806
# Lift: 13.370551463577423
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.024169296454427325
# Confidence: 0.35690789473684215
# Lift: 14.263077366078402
# =====================================
# Rule: colon-cancer -> MSH2
# Support: 0.005309077408576202
# Confidence: 0.7409326424870467
# Lift: 12.703386839839977
# =====================================
# Rule: colorectal-cancer -> MSH2
# Support: 0.026693892704659366
# Confidence: 0.3941885964912281
# Lift: 12.83853669466896
# =====================================
# Rule: endometrial-cancer -> MSH2
# Support: 0.0070168925190272876
# Confidence: 0.3480662983425414
# Lift: 7.488151554198364
# =====================================
# Rule: MSH2 -> hnpcc
# Support: 0.011249303879710414
# Confidence: 0.3393057110862262
# Lift: 7.299679974526759
# =====================================
# Rule: msi -> MSH2
# Support: 0.004195284945238537
# Confidence: 0.7290322580645161
# Lift: 12.499353196032935
# =====================================
# Rule: PMS2 -> MSH6
# Support: 0.023575273807313904
# Confidence: 0.3481359649122807
# Lift: 14.122051528482352
# =====================================
# Rule: colorectal-cancer -> MSH6
# Support: 0.0182661963987377
# Confidence: 0.4369449378330373
# Lift: 12.070884000546522
# =====================================
# Rule: endometrial-cancer -> MSH6
# Support: 0.006422869871913867
# Confidence: 0.31860036832412525
# Lift: 9.556237105579415
# =====================================
# Rule: MSH6 -> hnpcc
# Support: 0.006385743456469278
# Confidence: 0.4738292011019284
# Lift: 11.334448962416023
# =====================================
# Rule: PMS2 -> colorectal-cancer
# Support: 0.014330796361611286
# Confidence: 0.4361581920903954
# Lift: 12.049149645081846
# =====================================
# Rule: endometrial-cancer -> PMS2
# Support: 0.004677928346018192
# Confidence: 0.49606299212598426
# Lift: 15.097691178433204
# =====================================
# Rule: endometrial-cancer -> colorectal-cancer
# Support: 0.004900686838685725
# Confidence: 0.6
# Lift: 8.860197368421053
# =====================================
# Rule: colorectal-cancer -> hnpcc
# Support: 0.012214590681269724
# Confidence: 0.3684210526315789
# Lift: 10.177867746288797
# =====================================
# Rule: MSH2 -> MMR
# Support: 0.007685167997029887
# Confidence: 0.3219284603421462
# Lift: 9.425155520995336
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.0052719509931316135
# Confidence: 0.4947735191637631
# Lift: 15.058446032402212
# =====================================
# Rule: colorectal-cancer -> MSH2
# Support: 0.005606088732132913
# Confidence: 0.47784810126582283
# Lift: 8.192768050665142
# =====================================
# Rule: PMS2 -> MMR
# Support: 0.0052719509931316135
# Confidence: 0.6120689655172413
# Lift: 18.62833625560101
# =====================================
# Rule: colorectal-cancer -> MMR
# Support: 0.004566549099684425
# Confidence: 0.38924050632911394
# Lift: 9.311006250421567
# =====================================
# Rule: colorectal-cancer -> MMR
# Support: 0.00441804343790607
# Confidence: 0.37658227848101267
# Lift: 11.35861553290714
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.02305550399108966
# Confidence: 0.3952896244430299
# Lift: 16.034828365019592
# =====================================
# Rule: colorectal-cancer -> MSH2
# Support: 0.01837757564507147
# Confidence: 0.31508593252705286
# Lift: 15.182181739921589
# =====================================
# Rule: endometrial-cancer -> MSH2
# Support: 0.0062001113792463335
# Confidence: 0.30755064456721914
# Lift: 9.004213708063096
# =====================================
# Rule: MSH2 -> hnpcc
# Support: 0.006794134026359755
# Confidence: 0.5126050420168067
# Lift: 12.262004268847857
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.012994245405606088
# Confidence: 0.39548022598870053
# Lift: 12.880604458289781
# =====================================
# Rule: endometrial-cancer -> PMS2
# Support: 0.004343790607016893
# Confidence: 0.5707317073170732
# Lift: 17.370235634559737
# =====================================
# Rule: endometrial-cancer -> colorectal-cancer
# Support: 0.00441804343790607
# Confidence: 0.5409090909090909
# Lift: 9.273956946935941
# =====================================
# Rule: colorectal-cancer -> MSH2
# Support: 0.01199183218860219
# Confidence: 0.36170212765957444
# Lift: 11.780467724922174
# =====================================
# Rule: PMS2 -> colorectal-cancer
# Support: 0.013031371821050677
# Confidence: 0.3117229129662522
# Lift: 19.301739449990816
# =====================================
# Rule: endometrial-cancer -> PMS2
# Support: 0.004492296268795248
# Confidence: 0.6470588235294118
# Lift: 19.693253572615486
# =====================================
# Rule: colorectal-cancer -> hnpcc
# Support: 0.006459996287358456
# Confidence: 0.3112701252236136
# Lift: 9.388645938295667
# =====================================
# Rule: colon-cancer -> colorectal-cancer
# Support: 0.0042695377761277145
# Confidence: 0.30343007915567277
# Lift: 9.152171536459178
# =====================================
# Rule: colorectal-cancer -> hMLH1
# Support: 0.012511602004826435
# Confidence: 0.3687089715536105
# Lift: 25.015557049865233
# =====================================
# Rule: colorectal-cancer -> hMLH1
# Support: 0.008130684982364952
# Confidence: 0.49772727272727274
# Lift: 15.012636160032576
# =====================================
# Rule: colorectal-cancer -> hnpcc
# Support: 0.008242064228698718
# Confidence: 0.5591939546599496
# Lift: 16.86661721026399
# =====================================
# Rule: hMSH6 -> hMLH1
# Support: 0.006051605717467978
# Confidence: 0.6965811965811965
# Lift: 30.910073360649967
# =====================================
# Rule: hMLH1 -> hMSH2
# Support: 0.004900686838685725
# Confidence: 0.840764331210191
# Lift: 37.308051501065066
# =====================================
# Rule: hnpcc -> hMLH1
# Support: 0.007907926489697419
# Confidence: 0.35090609555189456
# Lift: 10.584160899989115
# =====================================
# Rule: ovarian-cancer -> breast-cancer
# Support: 0.004529422684239837
# Confidence: 0.3663663663663664
# Lift: 10.749540390063267
# =====================================
# Rule: MSH6 -> MSH2
# Support: 0.007091145349916466
# Confidence: 0.6282894736842105
# Lift: 18.394540188787186
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.005234824577687024
# Confidence: 0.4638157894736842
# Lift: 18.53542772918944
# =====================================
# Rule: colorectal-cancer -> MSH2
# Support: 0.004974939669574903
# Confidence: 0.44078947368421056
# Lift: 14.356305288614525
# =====================================
# Rule: MSH6 -> PMS2
# Support: 0.005160571746797847
# Confidence: 0.45723684210526316
# Lift: 18.547702322447687
# =====================================
# Rule: MSH6 -> colorectal-cancer
# Support: 0.004046779283460182
# Confidence: 0.35855263157894735
# Lift: 17.27659236418416
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.02246148134397624
# Confidence: 0.33168859649122806
# Lift: 14.38652551769924
# =====================================
# Rule: colorectal-cancer -> MSH2
# Support: 0.017263783181733803
# Confidence: 0.41296625222024863
# Lift: 15.470439504245336
# =====================================
# Rule: endometrial-cancer -> MSH2
# Support: 0.005940226471134212
# Confidence: 0.6299212598425197
# Lift: 18.4423142759329
# =====================================
# Rule: MSH2 -> MSH6
# Support: 0.006274364210135512
# Confidence: 0.465564738292011
# Lift: 13.63041981075578
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.0126229812511602
# Confidence: 0.38418079096045193
# Lift: 14.392085680834176
# =====================================
# Rule: endometrial-cancer -> PMS2
# Support: 0.004232411360683126
# Confidence: 0.44881889763779526
# Lift: 17.936108320287854
# =====================================
# Rule: endometrial-cancer -> colorectal-cancer
# Support: 0.004121032114349359
# Confidence: 0.437007874015748
# Lift: 14.233140370754741
# =====================================
# Rule: colorectal-cancer -> MSH2
# Support: 0.010358269909040282
# Confidence: 0.3124300111982083
# Lift: 11.704175732439138
# =====================================
# Rule: PMS2 -> MSH6
# Support: 0.012474475589381846
# Confidence: 0.37966101694915255
# Lift: 20.78489734049883
# =====================================
# Rule: endometrial-cancer -> PMS2
# Support: 0.00441804343790607
# Confidence: 0.468503937007874
# Lift: 19.00474931220947
# =====================================
# Rule: colorectal-cancer -> MSH6
# Support: 0.0058288472248004455
# Confidence: 0.4325068870523416
# Lift: 20.840023260742075
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.005012066085019491
# Confidence: 0.47038327526132406
# Lift: 19.08098421560808
# =====================================
# Rule: colorectal-cancer -> MSH2
# Support: 0.004232411360683126
# Confidence: 0.3972125435540069
# Lift: 19.13939152169441
# =====================================
# Rule: PMS2 -> MSH2
# Support: 0.012177464265825135
# Confidence: 0.3706214689265537
# Lift: 20.16704902128631
# =====================================
# Rule: endometrial-cancer -> PMS2
# Support: 0.0042695377761277145
# Confidence: 0.5609756097560975
# Lift: 22.755840434910372
# =====================================
# Rule: colorectal-cancer -> MSH2
# Support: 0.006051605717467978
# Confidence: 0.4565826330532213
# Lift: 22.000095208029542
# =====================================
# Rule: hnpcc -> colorectal-cancer
# Support: 0.007091145349916466
# Confidence: 0.43409090909090914
# Lift: 46.39777236652237
# =====================================
# Rule: PMS2 -> MSH6
# Support: 0.004974939669574903
# Confidence: 0.44078947368421056
# Lift: 19.118622340876346
# =====================================
# Rule: PMS2 -> colorectal-cancer
# Support: 0.011880452942268424
# Confidence: 0.3615819209039548
# Lift: 20.94453556892048
# =====================================
# Rule: PMS2 -> MSH6
# Support: 0.004195284945238537
# Confidence: 0.44488188976377957
# Lift: 19.296125122040905
# =====================================
# Rule: colorectal-cancer -> hnpcc
# Support: 0.005717467978466679
# Confidence: 0.4242424242424242
# Lift: 23.084787266605446
# =====================================

# %%
relations.drop(relations[(relations.Entity1 == 'breast') | (relations.Entity2 == 'breast')].index)
relations.sample(7)
# Out:
#                   Entity1 Entity2  ... Confidence       Lift
# 145                 RAD51   BRCA2  ...   0.495455   9.719642
# 29                  BRCA2  breast  ...   0.332425   6.521391
# 172  colorectal-carcinoma    MSH2  ...   0.703704  12.065092
# 35                    XPF   ERCC1  ...   0.545455  14.389636
# 210     colorectal-cancer    MSH2  ...   0.361702  11.780468
# 202    endometrial-cancer    MSH2  ...   0.307551   9.004214
# 61      colorectal-cancer    MLH1  ...   0.534539   4.200064
#
# [7 rows x 6 columns]

# %%
# from google.colab import files
# relations.to_csv('relations.csv')
# files.download('relations.csv')
